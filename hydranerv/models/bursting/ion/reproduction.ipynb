# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# %% [markdown]
# ## Adams Neuron

# %%
from hydranerv.models.bursting.ion.adams_neuron import AdamsNeuron

# %%
neuron = AdamsNeuron()
neuron.run(100)
neuron.disp()

# %% [markdown]
# ## Barreto Neuron

# %%
from hydranerv.models.bursting.ion.barreto_neuron import BarretoNeuron

# %%
t_total = 100
dt = 0.00001
neuron = BarretoNeuron(dt)
neuron.run(t_total, disp=True)
