# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from hydranerv.models.bursting.ion.barreto_neuron import BarretoNeuron
# %matplotlib widget

# %%
t_total = 100
dt = 0.00001

# %%
# default
neuron = BarretoNeuron(dt)
sol = neuron.run(t_total, disp=True)

# %% [markdown]
# ## k_bath
# the potassium concentration in the reservoir

# %%
neuron.k_bath = 7.62
sol = neuron.run(t_total, disp=True)

# %%
neuron.k_bath = 8.95
sol = neuron.run(t_total, disp=True)

# %% [markdown]
# ## phi
# rate of gate activation/inactivation

# %%
neuron = BarretoNeuron(dt)
neuron.phi = 0.03
sol = neuron.run(t_total, disp=True)

# %%
neuron = BarretoNeuron(dt)
neuron.phi = 1.0
sol = neuron.run(t_total, disp=True)

# %%
neuron = BarretoNeuron(dt)
neuron.phi = 5.0
sol = neuron.run(t_total, disp=True)
