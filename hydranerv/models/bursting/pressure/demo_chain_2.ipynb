# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
from hydranerv.models.bursting.pressure.chain_2 import Chain2

# %%
chain = Chain2(gc=0)
chain.run(100)
chain.disp(spike=False, figsize=(12, 6))

# %%
chain = Chain2(gc=.1)
chain.run(100)
chain.disp(spike=False, figsize=(12, 6))

# %%
chain = Chain2(gc=.2)
chain.run(100)
chain.disp(spike=False, figsize=(12, 6))

# %%
chain = Chain2(gc=.3)
chain.run(100)
chain.disp(spike=False, figsize=(12, 6))
