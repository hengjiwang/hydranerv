# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
from hydranerv.models.bursting.pressure.random_network_2 import RandomNetwork2

# %%
randnet = RandomNetwork2(gc=0)
randnet.run(100)
randnet.disp(spike=False)

# %%
randnet = RandomNetwork2(gc=.05)
randnet.run(100)
randnet.disp(spike=False)

# %%
randnet = RandomNetwork2(gc=.5)
randnet.run(100)
randnet.disp(spike=False)
