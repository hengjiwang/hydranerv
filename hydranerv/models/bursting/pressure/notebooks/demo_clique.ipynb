# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
from hydranerv.models.bursting.pressure.clique import Clique

# %%
clique = Clique(gc=.05)
clique.run(200)
clique.disp(spike=False)

# %%
clique = Clique(gc=.075)
clique.run(200)
clique.disp(spike=False)

# %%
clique = Clique(gc=.1)
clique.run(200)
clique.disp(spike=False)

# %%
clique = Clique(gc=.2)
clique.run(200)
clique.disp(spike=False)

# %%
clique = Clique(gc=.5)
clique.run(200)
clique.disp(spike=False)

# %%
clique = Clique(gc=.6)
clique.run(200)
clique.disp(spike=False)

# %%
clique.disp_conn_mat()
