# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
from hydranerv.models.bursting.pressure.random_network import RandomNetwork

# %%
randnet = RandomNetwork(gc=.05)
randnet.run(100)
randnet.disp(spike=False)

# %%
randnet = RandomNetwork(gc=.1)
randnet.run(100)
randnet.disp(spike=False)

# %%
randnet = RandomNetwork(gc=.15)
randnet.run(100)
randnet.disp(spike=False)

# %%
randnet.disp_conn_mat()
