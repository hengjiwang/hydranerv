# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
from hydranerv.models.bursting.pressure.clique_2 import Clique2

# %%
clique = Clique2(gc=0)
clique.run(100)
clique.disp(spike=False)

# %%
clique = Clique2(gc=.01)
clique.run(100)
clique.disp(spike=False)

# %%
clique = Clique2(gc=.05)
clique.run(100)
clique.disp(spike=False)
