# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from cyl_even_network import CylEvenNetwork

# %%
ntwk = CylEvenNetwork(num_lon=10,
                      num_cir=20,
                      gc=800, #700,
                      tmax=1000,
                      pacemakers=range(200),
                      wnoise=0,
                      prob_lon=1,
                      prob_cir=.2,
                      seed=123)

# %%
# %matplotlib inline
ntwk.disp_network(figsize=(10, 10), show_pm=False)

# %%
# cut region
ntwk.cut(phi_start=np.pi,
         phi_end=2*np.pi,
         z_start=.25,
         z_end=.75)

# %%
# %matplotlib inline
ntwk.disp_network(figsize=(10, 10), show_pm=False)

# %%
ntwk.run()
# Out:
# 100%|███████████████████████████████████| 99999/99999 [01:34<00:00, 1055.02it/s]

# %%
# %matplotlib inline
ntwk.disp(figsize=(15, 15), style='spike')
