# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from cyl_network import CylNetwork

# %%
ntwk = CylNetwork(num=150,
                  num_hyp=40,
                  num_ped=40,
                  gc=700,
                  tmax=1000,
                  pacemakers=range(40),
                  wnoise=0,
                  lambda_d=.15)

# for nrn in ntwk.neurons:
#     nrn.k_in = 75

# %%
# %matplotlib widget
ntwk.disp_network(figsize=(8, 8))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ntwk.run()
# Out:
# 100%|█████████████████████████████████████████| 99999/99999 [01:31<00:00, 1096.74it/s]

# %%
# %matplotlib widget
ntwk.disp(figsize=(8, 8), style='spike')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
plt.figure()
plt.plot(ntwk.neurons[0].v_train)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
