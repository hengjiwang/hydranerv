# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from cyl_network import CylNetwork

# %%
ntwk = CylNetwork(num=150,
                  num_hyp=40,
                  num_ped=40,
                  lambda_d=.15)

# %%
ntwk.disp_network(figsize=(8, 8))
