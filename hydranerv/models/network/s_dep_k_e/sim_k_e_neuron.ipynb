# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from k_e_neuron import KENeuron

# %%
nrn = KENeuron()
nrn.run()
nrn.disp(figsize=(10,5), disp_stress=True)

# %%
nrn = KENeuron(s=.002)
nrn.run()
nrn.disp(figsize=(10,5), disp_stress=True)
