# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from cyl_even_network import CylEvenNetwork

# %%
ntwk = CylEvenNetwork(num_lon=10,
                      num_cir=20,
                      gc=800, #700,
                      tmax=1000,
                      pacemakers=range(40),
                      wnoise=0,
                      prob_lon=1,
                      prob_cir=.2)

# %%
# modify pacemakers
for pm in ntwk.pacemakers:
    neuron = ntwk.neurons[pm]
#     neuron.s = .007
    neuron.k_a = 8000
    neuron.k_e = 1000

# %%
# %matplotlib inline
ntwk.disp_network(figsize=(10, 10))

# %%
ntwk.run()
# Out:
# 100%|█████████████████████████████████████████| 99999/99999 [01:33<00:00, 1064.77it/s]

# %%
# %matplotlib inline
ntwk.disp(figsize=(15, 15), style='spike')

# %%
ntwk.neurons[0].k_a
# Out:
# 8000

# %%
# %matplotlib inline
plt.figure(figsize=(15, 3))
plt.plot(ntwk.neurons[0].v_train[40000:60000])
plt.show()
