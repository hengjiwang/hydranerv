# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from cyl_ecto_even_network import CylEctoEvenNetwork

# %%
ntwk = CylEctoEvenNetwork(tmax=400,
                      gc_cb=500,
                      gc_rp=500,
                      pm_cb=range(400),
                      tau_inh_cb=5,
                      tau_inh_rp=5,
                      a_inh_cb=100,
                      a_inh_rp=100,
                      prob_cb_to_rb=.3,
                      prob_rp_to_cb=.3,
                      prob_random=0,
                      seed=114514)

# %%
# %matplotlib inline
ntwk.disp_network(edge_type='rp_to_cb')

# %%
ntwk.run()
# Out:
# 100%|████████████████████████████████████| 39999/39999 [01:41<00:00, 395.00it/s]

# %%
ntwk.cbnet.disp()
ntwk.rpnet.disp()

# %%
plt.figure(figsize=(20,3))
plt.plot(ntwk.cbnet.neurons[-1].v_train)
plt.plot(ntwk.rpnet.neurons[-1].v_train)
plt.show()
