# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from cyl_ecto_even_network import CylEctoEvenNetwork

# %%
ntwk = CylEctoEvenNetwork(tmax=500,
                          num_lon=10,
                          num_cir=10,
                          gc_cb=500,
                          gc_rp=500,
                          pm_cb=range(400),
                          tau_inh_cb=5,
                          tau_inh_rp=5,
                          a_inh_cb=25, # 25,
                          a_inh_rp=100, # 100,
                          # tau_inh_cb=75,
                          # tau_inh_rp=10,
                          # a_inh_cb=2.5,
                          # a_inh_rp=50,
                          prob_cb_to_rb=None,
                          prob_rp_to_cb=None,
                          prob_random=None,
                          method='gradient',
                          seed=114514)

# %%
for neuron in ntwk.rpnet.neurons:
    neuron.g_s = 2

# %%
# cut region
ntwk.cut(phi_start=0,
         phi_end=2*np.pi,
         z_start=0,
         z_end=.5)

# %%
# %matplotlib inline
ntwk.disp_network(edge_type='cb_to_rp')
ntwk.disp_network(edge_type='rp_to_cb')

# %%
ntwk.run()
# Out:
# 100%|████████████████████████████████████| 49999/49999 [00:54<00:00, 919.47it/s]

# %%
# %matplotlib inline
ntwk.cbnet.disp()
ntwk.rpnet.disp()
