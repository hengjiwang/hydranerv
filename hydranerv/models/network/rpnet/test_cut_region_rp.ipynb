# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from cyl_rp_even_network import CylRPEvenNetwork

# %%
ntwk = CylRPEvenNetwork(tmax=400,
                        num_lon=10,
                        num_cir=20,
                        gc=100,
                        prob_lon=1,
                        prob_cir=.2,
                        phi_offset=np.pi/36,
                        seed=123)

# %%
# %matplotlib inline
ntwk.disp_network(figsize=(10, 10))

# %%
# cut region
ntwk.cut(phi_start=np.pi,
         phi_end=2*np.pi,
         z_start=.25,
         z_end=.75)

# %%
# %matplotlib inline
ntwk.disp_network(figsize=(10, 10))

# %%
ntwk.run([35000] * 200)
# Out:
# 100%|███████████████████████████████████| 39999/39999 [00:29<00:00, 1339.32it/s]

# %%
# %matplotlib inline
ntwk.disp(figsize=(15, 15), style='spike')
