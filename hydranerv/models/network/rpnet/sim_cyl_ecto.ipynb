# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt
from cyl_ecto_network import CylEctoNetwork

# %%
def plot_train(train):
    plt.figure(figsize=(20,3))
    plt.plot(train)
    plt.show()

# %%
ntwk = CylEctoNetwork(tmax=400,
                      num_rp=200,
                      gc_cb=800,
                      gc_rp=800,
                      pm_cb=range(400),
                      lambda_d=(.1, .1),
                      seed=114514)

# %%
ntwk.disp_network(edge_type='rp')

# %%
ntwk.run()
# Out:
# 100%|████████████████████████████████████| 39999/39999 [02:28<00:00, 269.11it/s]

# %%
ntwk.cbnet.disp()
ntwk.rpnet.disp()

# %%
plot_train(ntwk.cbnet.neurons[0].v_train)
