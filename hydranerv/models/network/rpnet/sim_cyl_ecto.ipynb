# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from cyl_ecto_network import CylEctoNetwork

# %%
def plot_train(train):
    plt.figure(figsize=(20,3))
    plt.plot(train)
    plt.show()

# %%
ntwk = CylEctoNetwork(tmax=400,
                      num_rp=200,
                      gc_cb=800,
                      gc_rp=500,
                      pm_cb=range(400),
                      tau_inh_cb=5,
                      tau_inh_rp=5,
                      a_inh_cb=100,
                      a_inh_rp=100,
                      lambda_d=(.1, .05),
                      seed=114514)

# %%
ntwk.disp_network(edge_type='cb_to_rp')

# %%
ntwk.run()
# Out:
# 100%|████████████████████████████████████| 39999/39999 [02:34<00:00, 259.55it/s]

# %%
ntwk.cbnet.disp()
ntwk.rpnet.disp()

# %%
# plot_train(ntwk.rpnet.neurons[2].v_train)
plt.figure(figsize=(20,3))
plt.plot(ntwk.cbnet.neurons[0].v_train)
plt.plot(ntwk.rpnet.neurons[0].v_train)
plt.show()
