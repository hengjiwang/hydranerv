# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
fpath = '~/Documents/hydrafiles/nerve/videos.nosync/wataru/Fig 3/Osmo/High/substacks/data/'
df = pd.read_csv(fpath + '6.csv')
data = df['Mean'].values
plt.figure(figsize=(20, 5))
plt.plot(data[9000:], lw=.5)
plt.show()

# %%
df[10000:12000].to_csv(fpath + '3_5.csv')

# %%
fpath = '~/Documents/hydrafiles/nerve/videos.nosync/wataru/Fig 3/Osmo/High/substacks/data/'
df = pd.read_csv(fpath + '4_1.csv')

data = df['Mean'].values

plt.figure(figsize=(20, 5))
plt.plot(data[:], lw=.5)
plt.show()
