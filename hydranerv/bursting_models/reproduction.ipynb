# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from hydranerv.bursting_models.adams_neuron import AdamsNeuron

# %% [markdown]
# ## Adams Neuron

# %%
neuron = AdamsNeuron()
neuron.run(100)
neuron.disp()

# %% [markdown]
# ## Barreto Neuron
